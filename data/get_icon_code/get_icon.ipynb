# %%
import pandas as pd

data = pd.read_json(r'..\all_templates.json.')

# %%
data
# Out:
#       id  name                                     scientificName
# 0     68  东京樱花                               Cerasus × yedoensis   \
# 1    223   再力花                                    Thalia dealbata
# 2    222    樱桃               Prunus pseudocerasus (Lindl.) G. Don
# 3     11    池杉  Taxodium distichum var. imbricatum (Nuttall) C...
# 4     30    杜仲                                  Eucommia ulmoides
# ..   ...   ...                                                ...
# 189  125   六月雪                                  Serissa japonica
# 190  150    杜英                              Elaeocarpus decipiens
# 191  111    柊树                           Osmanthus heterophyllus
# 192  152     柚                                      Citrus maxima
# 193  110    丁香                              Syringa oblata Lindl.
#
#                     scientificNameEn name2 branch habit  period
# 0                   (Mats.) Yü et Li  None    蔷薇科    乔木     NaN  \
# ...

# %%
icon = []
for i in range(len(data)):
  icon.append(data.loc[i]["icon"])

# %%
icon = list(set(icon))

# %%
len(icon)
# Out:
# 82

# %%
import json
with open('icon.json', 'w') as f:
    json.dump(icon, f)
